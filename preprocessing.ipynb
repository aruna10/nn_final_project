# %%
import os
import cv2
import numpy as np
from skimage import exposure
from skimage.restoration import denoise_nl_means
from skimage.transform import resize
from albumentations import (
    Compose,
    HorizontalFlip,
    VerticalFlip,
    RandomRotate90,
    GaussNoise
)

# %%
# import matplotlib.pyplot as plt

# # Define preprocessing functions
# def resize_and_normalize(image, width, height):
#     # Resize the image
#     resized_image = resize(image, (height, width), mode='reflect', anti_aliasing=True)
#     # Normalize pixel values to range [0, 1]
#     normalized_image = resized_image / 255.0
#     return normalized_image

# %%
# def augment_image(image):
#     # Define the augmentation pipeline
#     augmentation_transform = Compose([
#         HorizontalFlip(p=0.5),
#         VerticalFlip(p=0.5),
#         RandomRotate90(p=0.5),
#         GaussNoise(p=0.2)
#     ])
#     # Apply augmentation
#     augmented_image = augmentation_transform(image=image)["image"]
#     return augmented_image

# %%
# def reduce_noise(image):
#     # Apply Non-Local Means denoising
#     denoised_image = denoise_nl_means(image, h=0.1)
#     return denoised_image

# %%
# def enhance_contrast(image):
#     # Apply histogram equalization to enhance contrast
#     contrast_enhanced_image = exposure.equalize_hist(image)
#     return contrast_enhanced_image

# %%
# def extract_roi(image):
#     # Simple ROI extraction: here, we'll just return the full image
    
#     return image

# %%
# # Paths to folders
# folder_path = "H:/BIG DATA/nn_final_project/dataset/boneage-training-dataset"
# output_folder = "H:/BIG DATA/nn_final_project/dataset/preprocessed-boneage-training-dataset"

# %%
# # Ensure output folder exists
# if not os.path.exists(output_folder):
#     os.makedirs(output_folder)

# %%
# # Iterate through each file in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".png"):
#         # Read the image
#         image_path = os.path.join(folder_path, filename)
#         image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

#         # Step 1: Image resizing and normalization
#         resized_normalized_image = resize_and_normalize(image, desired_width, desired_height)

#         # Step 2: Image augmentation
#         augmented_image = augment_image(resized_normalized_image)

#         # Step 3: Noise reduction
#         denoised_image = reduce_noise(augmented_image)

#         # Step 4: Contrast enhancement
#         contrast_enhanced_image = enhance_contrast(denoised_image)

#         # Step 5: ROI extraction
#         roi = extract_roi(contrast_enhanced_image)

#         # Save the preprocessed image to the output folder
#         output_path = os.path.join(output_folder, filename)
#         cv2.imwrite(output_path, roi)

# %%
# Step 1: Image resizing and normalization
def resize_and_normalize(image, desired_width, desired_height):
    resized_image = resize(image, (desired_height, desired_width))
    normalized_image = exposure.rescale_intensity(resized_image, out_range=(0, 255))
    return normalized_image

# %%
# Step 2: Image augmentation
def augment_image(image):
    augmentation_transform = Compose([
        HorizontalFlip(p=0.5),
        VerticalFlip(p=0.5),
        RandomRotate90(p=0.5),
        GaussNoise(p=0.2)
    ])
    augmented_image = augmentation_transform(image=image)["image"]
    return augmented_image

# %%
# Step 3: Noise reduction
def reduce_noise(image):
    denoised_image = denoise_nl_means(image, patch_size=5, patch_distance=3, h=0.8)
    return denoised_image

# %%
# Step 4: Contrast enhancement
def enhance_contrast(image, alpha=1.5, beta=0):
    enhanced_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)
    return enhanced_image

# %%
# Step 5: ROI extraction (Example: Keep only the center region)
def extract_roi(image):
    height, width = image.shape[:2]
    roi_width = int(width * 0.8)
    roi_height = int(height * 0.9)
    x = int((width - roi_width) / 2)
    y = int((height - roi_height) / 2)
    roi = image[y:y+roi_height, x:x+roi_width]
    return roi

# %%
# Path to the folder containing the raw PNG images
folder_path = "H:/BIG DATA/nn_final_project/dataset/boneage-training-dataset"

# Output folder for preprocessed images
output_folder = "H:/BIG DATA/nn_final_project/demo images"

# Desired dimensions for resizing
desired_width = 256
desired_height = 256

# %%
# def resize_and_normalize(folder_path, width, height):
#     resized_image = cv2.resize(image, (width, height))
#     normalized_image = resized_image / 255.0  # Normalize to 0-1 range
#     return (normalized_image * 255).astype(np.uint8)  # Convert back to uint8

# def augment_image(folder_path):
#     # Assuming some augmentation that returns float32, you can convert back to uint8 if needed
#     augmented_image = some_augmentation(folder_path)
#     return augmented_image.astype(np.uint8)  # Ensure consistent data type

# %%
# folder_path = "H:/BIG DATA/nn_final_project/dataset/boneage-training-dataset"
# output_folder = "H:/BIG DATA/nn_final_project/demo images"

# os.makedirs(output_folder, exist_ok=True)

# # Function to apply augmentation
# def augment_image(image):
#     # Example augmentations
#     flipped = cv2.flip(image, 1)  # Horizontal flip
#     rotated = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)  # Rotate 90 degrees
#     return flipped, rotated

# # Iterate through each file in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith((".png", ".jpg", ".jpeg")):  # Check for image files
#         # Read the image
#         image_path = os.path.join(folder_path, filename)
#         image = cv2.imread(image_path, cv2.IMREAD_COLOR)  # Use IMREAD_COLOR to keep the original channels

#         # Apply augmentation
#         flipped_image, rotated_image = augment_image(image)

#         # Save augmented images
#         flipped_filename = f"flipped_{filename}"
#         rotated_filename = f"rotated_{filename}"
#         cv2.imwrite(os.path.join(output_folder, flipped_filename), flipped_image)
#         cv2.imwrite(os.path.join(output_folder, rotated_filename), rotated_image)

#         print(f"Augmented images saved for {filename}")

# print("All images have been augmented and saved.")
# Out:
# Augmented images saved for 10000.png
# Augmented images saved for 10001.png
# Augmented images saved for 10002.png
# Augmented images saved for 10003.png
# Augmented images saved for 10004.png
# Augmented images saved for 10005.png
# Augmented images saved for 10006.png
# Augmented images saved for 10007.png
# Augmented images saved for 10008.png
# Augmented images saved for 10009.png
# Augmented images saved for 10010.png
# Augmented images saved for 10011.png
# Augmented images saved for 10012.png
# Augmented images saved for 10013.png
# Augmented images saved for 10014.png
# Augmented images saved for 10015.png
# Augmented images saved for 10016.png
# Augmented images saved for 10017.png
# Augmented images saved for 10019.png
# Augmented images saved for 10020.png
# Augmented images saved for 10021.png
# Augmented images saved for 10022.png
# Augmented images saved for 10023.png
# Augmented images saved for 10024.png
# Augmented images saved for 10025.png
# Augmented images saved for 10026.png
# Augmented images saved for 10029.png
# Augmented images saved for 10030.png
# Augmented images saved for 10031.png
# Augmented images saved for 10033.png
# Augmented images saved for 10035.png
# Augmented images saved for 10036.png
# Augmented images saved for 10037.png
# Augmented images saved for 10038.png
# Augmented images saved for 10039.png
# Augmented images saved for 10040.png
# Augmented images saved for 10041.png
# Augmented images saved for 10042.png
# Augmented images saved for 10043.png
# Augmented images saved for 10044.png
# Augmented images saved for 10045.png
# Augmented images saved for 10046.png
# Augmented images saved for 10047.png
# Augmented images saved for 10048.png
# Augmented images saved for 10049.png
# Augmented images saved for 10051.png
# Augmented images saved for 10052.png
# Augmented images saved for 10053.png
# Augmented images saved for 10054.png
# Augmented images saved for 10055.png
# Augmented images saved for 10056.png
# Augmented images saved for 10057.png
# Augmented images saved for 10058.png
# Augmented images saved for 10059.png
# Augmented images saved for 10060.png
# Augmented images saved for 10061.png
# Augmented images saved for 10062.png
# Augmented images saved for 10063.png
# Augmented images saved for 10064.png
# Augmented images saved for 10066.png
# Augmented images saved for 10067.png
# Augmented images saved for 10068.png
# Augmented images saved for 10069.png
# Augmented images saved for 10070.png
# Augmented images saved for 10071.png
# Augmented images saved for 10073.png
# Augmented images saved for 10074.png
# Augmented images saved for 10075.png
# Augmented images saved for 10076.png
# Augmented images saved for 10077.png
# Augmented images saved for 10078.png
# Augmented images saved for 10079.png
# Augmented images saved for 10080.png
# Augmented images saved for 10081.png
# Augmented images saved for 10083.png
# Augmented images saved for 10084.png
# Augmented images saved for 10085.png
# Augmented images saved for 10086.png
# Augmented images saved for 10087.png
# Augmented images saved for 10088.png
# Augmented images saved for 10089.png
# Augmented images saved for 10090.png
# Augmented images saved for 10091.png
# Augmented images saved for 10092.png
# Augmented images saved for 10093.png
# Augmented images saved for 10094.png
# Augmented images saved for 10095.png
# Augmented images saved for 10096.png
# Augmented images saved for 10097.png
# Augmented images saved for 10099.png
# Augmented images saved for 10100.png
# Augmented images saved for 10102.png
# Augmented images saved for 10103.png
# Augmented images saved for 10104.png
# Augmented images saved for 10105.png
# Augmented images saved for 10106.png
# Augmented images saved for 10107.png
# Augmented images saved for 10108.png
# Augmented images saved for 10109.png
# Augmented images saved for 10110.png
# Augmented images saved for 10111.png
# Augmented images saved for 10112.png
# Augmented images saved for 10113.png
# Augmented images saved for 10114.png
# Augmented images saved for 10115.png
# Augmented images saved for 10116.png
# Augmented images saved for 10117.png
# Augmented images saved for 10118.png
# Augmented images saved for 10120.png
# Augmented images saved for 10121.png
# Augmented images saved for 10122.png
# Augmented images saved for 10123.png
# Augmented images saved for 10125.png
# Augmented images saved for 10126.png
# Augmented images saved for 10128.png
# Augmented images saved for 10130.png
# Augmented images saved for 10131.png
# Augmented images saved for 10132.png
# Augmented images saved for 10134.png
# Augmented images saved for 10136.png
# Augmented images saved for 10137.png
# Augmented images saved for 10138.png
# Augmented images saved for 10139.png
# Augmented images saved for 10140.png
# Augmented images saved for 10141.png
# Augmented images saved for 10143.png
# Augmented images saved for 10144.png
# Augmented images saved for 10145.png
# Augmented images saved for 10146.png
# Augmented images saved for 10147.png
# Augmented images saved for 10148.png
# Augmented images saved for 10149.png
# Augmented images saved for 10150.png
# Augmented images saved for 10151.png
# Augmented images saved for 10152.png
# Augmented images saved for 10153.png
# Augmented images saved for 10154.png
# Augmented images saved for 10155.png
# Augmented images saved for 10156.png
# Augmented images saved for 10157.png
# Augmented images saved for 10158.png
# Augmented images saved for 10159.png
# Augmented images saved for 10160.png
# Augmented images saved for 10161.png
# Augmented images saved for 10163.png
# Augmented images saved for 10164.png
# Augmented images saved for 10165.png
# Augmented images saved for 10166.png
# Augmented images saved for 10168.png
# Augmented images saved for 10169.png
# Augmented images saved for 10170.png
# Augmented images saved for 10171.png
# Augmented images saved for 10174.png
# Augmented images saved for 10175.png
# Augmented images saved for 10176.png
# Augmented images saved for 10177.png
# Augmented images saved for 10178.png
# Augmented images saved for 10179.png
# Augmented images saved for 10180.png
# Augmented images saved for 10181.png
# Augmented images saved for 10182.png
# Augmented images saved for 10183.png
# Augmented images saved for 10184.png
# Augmented images saved for 10185.png
# Augmented images saved for 10186.png
# Augmented images saved for 10187.png
# Augmented images saved for 10188.png
# Augmented images saved for 10190.png
# Augmented images saved for 10192.png
# Augmented images saved for 10194.png
# Augmented images saved for 10195.png
# Augmented images saved for 10196.png
# Augmented images saved for 10197.png
# Augmented images saved for 10198.png
# Augmented images saved for 10199.png
# Augmented images saved for 10200.png
# Augmented images saved for 10201.png
# Augmented images saved for 10202.png
# Augmented images saved for 10203.png
# Augmented images saved for 10204.png
# Augmented images saved for 10205.png
# Augmented images saved for 10206.png
# Augmented images saved for 10207.png
# Augmented images saved for 10208.png
# Augmented images saved for 10209.png
# Augmented images saved for 10210.png
# Augmented images saved for 10211.png
# Augmented images saved for 10212.png
# Augmented images saved for 10214.png
# Augmented images saved for 10216.png
# Augmented images saved for 10217.png
# Augmented images saved for 10219.png
# Augmented images saved for 10220.png
# Augmented images saved for 10221.png
# Augmented images saved for 10222.png
# Augmented images saved for 10223.png
# Augmented images saved for 10224.png
# Augmented images saved for 10225.png
# Augmented images saved for 10226.png
# Augmented images saved for 10227.png
# Augmented images saved for 10228.png
# Augmented images saved for 10229.png
# Augmented images saved for 10230.png
# Augmented images saved for 10231.png
# Augmented images saved for 10232.png
# Augmented images saved for 10233.png
# Augmented images saved for 10234.png
# Augmented images saved for 10235.png
# Augmented images saved for 10236.png
# Augmented images saved for 10237.png
# Augmented images saved for 10238.png
# Augmented images saved for 10239.png
# Augmented images saved for 10240.png
# Augmented images saved for 10242.png
# Augmented images saved for 10243.png
# Augmented images saved for 10244.png
# Augmented images saved for 10245.png
# Augmented images saved for 10246.png
# Augmented images saved for 10247.png
# Augmented images saved for 10248.png
# Augmented images saved for 10249.png
# Augmented images saved for 10250.png
# Augmented images saved for 10251.png
# Augmented images saved for 10252.png
# Augmented images saved for 10253.png
# Augmented images saved for 10254.png
# Augmented images saved for 10256.png
# Augmented images saved for 10257.png
# Augmented images saved for 10258.png
# Augmented images saved for 10259.png
# Augmented images saved for 10260.png
# Augmented images saved for 10261.png
# Augmented images saved for 10262.png
# Augmented images saved for 10264.png
# Augmented images saved for 10265.png
# Augmented images saved for 10266.png
# Augmented images saved for 10267.png
# Augmented images saved for 10270.png
# Augmented images saved for 10271.png
# Augmented images saved for 10272.png
# Augmented images saved for 10273.png
# Augmented images saved for 10274.png
# Augmented images saved for 10275.png
# Augmented images saved for 10276.png
# Augmented images saved for 10277.png
# Augmented images saved for 10278.png
# Augmented images saved for 10279.png
# Augmented images saved for 10280.png
# Augmented images saved for 10281.png
# Augmented images saved for 10282.png
# Augmented images saved for 10284.png
# Augmented images saved for 10285.png
# Augmented images saved for 10286.png
# Augmented images saved for 10287.png
# Augmented images saved for 10288.png
# Augmented images saved for 10289.png
# Augmented images saved for 10290.png
# Augmented images saved for 10291.png
# Augmented images saved for 10292.png
# Augmented images saved for 10293.png
# Augmented images saved for 10294.png
# Augmented images saved for 10296.png
# Augmented images saved for 10297.png
# Augmented images saved for 10298.png
# Augmented images saved for 10299.png
# Augmented images saved for 10300.png
# Augmented images saved for 10301.png
# Augmented images saved for 10302.png
# Augmented images saved for 10303.png
# Augmented images saved for 10304.png
# Augmented images saved for 10305.png
# Augmented images saved for 10306.png
# Augmented images saved for 10307.png
# Augmented images saved for 10308.png
# Augmented images saved for 10309.png
# Augmented images saved for 10310.png
# Augmented images saved for 10311.png
# Augmented images saved for 10312.png
# Augmented images saved for 10313.png
# Augmented images saved for 10314.png
# Augmented images saved for 10315.png
# Augmented images saved for 10316.png
# Augmented images saved for 10318.png
# Augmented images saved for 10319.png
# Augmented images saved for 10320.png
# Augmented images saved for 10321.png
# Augmented images saved for 10322.png
# Augmented images saved for 10323.png
# Augmented images saved for 10324.png
# Augmented images saved for 10325.png
# Augmented images saved for 10326.png
# Augmented images saved for 10327.png
# Augmented images saved for 10328.png
# Augmented images saved for 10329.png
# Augmented images saved for 10330.png
# Augmented images saved for 10331.png
# Augmented images saved for 10332.png
# Augmented images saved for 10333.png
# Augmented images saved for 10334.png
# Augmented images saved for 10335.png
# Augmented images saved for 10336.png
# Augmented images saved for 10337.png
# Augmented images saved for 10338.png
# Augmented images saved for 10339.png
# Augmented images saved for 10340.png
# Augmented images saved for 10341.png
# Augmented images saved for 10342.png
# Augmented images saved for 10343.png
# Augmented images saved for 10345.png
# Augmented images saved for 10346.png
# Augmented images saved for 10347.png
# Augmented images saved for 10348.png
# Augmented images saved for 10351.png
# Augmented images saved for 10352.png
# Augmented images saved for 10353.png
# Augmented images saved for 10354.png
# Augmented images saved for 10356.png
# Augmented images saved for 10357.png
# Augmented images saved for 10358.png
# Augmented images saved for 10360.png
# Augmented images saved for 10361.png
# Augmented images saved for 10362.png
# Augmented images saved for 10363.png
# Augmented images saved for 10364.png
# Augmented images saved for 10366.png
# Augmented images saved for 10367.png
# Augmented images saved for 10368.png
# Augmented images saved for 10369.png
# Augmented images saved for 10370.png
# Augmented images saved for 10371.png
# Augmented images saved for 10372.png
# Augmented images saved for 10373.png
# Augmented images saved for 10374.png
# Augmented images saved for 10375.png
# Augmented images saved for 10376.png
# Augmented images saved for 10377.png
# Augmented images saved for 10378.png
# Augmented images saved for 10379.png
# Augmented images saved for 10381.png
# Augmented images saved for 10382.png
# Augmented images saved for 10383.png
# Augmented images saved for 10384.png
# Augmented images saved for 10385.png
# Augmented images saved for 10386.png
# Augmented images saved for 10387.png
# Augmented images saved for 10388.png
# Augmented images saved for 10390.png
# Augmented images saved for 10391.png
# Augmented images saved for 10392.png
# Augmented images saved for 10393.png
# Augmented images saved for 10394.png
# Augmented images saved for 10395.png
# Augmented images saved for 10396.png
# Augmented images saved for 10397.png
# Augmented images saved for 10398.png
# Augmented images saved for 10399.png
# Augmented images saved for 10400.png
# Augmented images saved for 10402.png
# Augmented images saved for 10403.png
# Augmented images saved for 10404.png
# Augmented images saved for 10405.png
# Augmented images saved for 10406.png
# Augmented images saved for 10408.png
# Augmented images saved for 10410.png
# Augmented images saved for 10411.png
# Augmented images saved for 10412.png
# Augmented images saved for 10413.png
# Augmented images saved for 10414.png
# Augmented images saved for 10415.png
# Augmented images saved for 10417.png
# Augmented images saved for 10418.png
# Augmented images saved for 10419.png
# Augmented images saved for 10420.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 26
#      24 flipped_filename = f"flipped_{filename}"
#      25 rotated_filename = f"rotated_{filename}"
# ---> 26 cv2.imwrite(os.path.join(output_folder, flipped_filename), flipped_image)
#      27 cv2.imwrite(os.path.join(output_folder, rotated_filename), rotated_image)
#      29 print(f"Augmented images saved for {filename}")
#
# KeyboardInterrupt:

# %%
# import os
# import cv2

# # Define your folder paths
# folder_path = "H:/BIG DATA/nn_final_project/dataset/boneage-training-dataset"
# output_folder = "H:/BIG DATA/nn_final_project/dataset/preprocessed-boneage-training-dataset"

# # Ensure the output directory exists
# os.makedirs(output_folder, exist_ok=True)

# # Iterate through each file in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith((".png", ".jpg", ".jpeg")):  # Check for image files
#         # Read the image
#         image_path = os.path.join(folder_path, filename)
#         image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale

#         # Step 1: Image resizing and normalization
#         resized_normalized_image = resize_and_normalize(image, desired_width, desired_height)

#         # Step 2: Image augmentation
#         augmented_image = augment_image(resized_normalized_image)

#         # Step 3: Noise reduction
#         denoised_image = reduce_noise(augmented_image)

#         # Step 4: Contrast enhancement
#         contrast_enhanced_image = enhance_contrast(denoised_image)

#         # Step 5: ROI extraction
#         roi_image = extract_roi(contrast_enhanced_image)

#         # Save the preprocessed image to the output folder
#         output_path = os.path.join(output_folder, filename)
#         cv2.imwrite(output_path, roi_image)

#         print(f"Preprocessed image saved for {filename}")

# print("All images have been processed and saved.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 25
#      22 augmented_image = augment_image(resized_normalized_image)
#      24 # Step 3: Noise reduction
# ---> 25 denoised_image = reduce_noise(augmented_image)
#      27 # Step 4: Contrast enhancement
#      28 contrast_enhanced_image = enhance_contrast(denoised_image)
#
# Cell In[4], line 3, in reduce_noise(image)
#       2 def reduce_noise(image):
# ----> 3     denoised_image = denoise_nl_means(image, patch_size=5, patch_distance=3, h=0.8)
#       4     return denoised_image
#
# File h:\BIG DATA\nn_final_project\venv\lib\site-packages\skimage\_shared\utils.py:438, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     435 channel_axis = kwargs.get('channel_axis', None)
#     437 if channel_axis is None:
# --> 438     return func(*args, **kwargs)
#     440 # TODO: convert scalars to a tuple in anticipation of eventually
#     441 #       supporting a tuple of channel axes. Right now, only an
#     442 #       integer or a single-element tuple is supported, though.
#     443 if np.isscalar(channel_axis):
#
# File h:\BIG DATA\nn_final_project\venv\lib\site-packages\skimage\restoration\non_local_means.py:154, in denoise_nl_means(image, patch_size, patch_distance, h, fast_mode, sigma, preserve_range, channel_axis)
#     152 if channel_axis is None:
#     153     multichannel = False
# --> 154     image = image[..., np.newaxis]
#     155 else:
#     156     multichannel = True
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
import cv2
import numpy as np

def resize_and_normalize(image, width, height):
    resized_image = cv2.resize(image, (width, height))
    normalized_image = resized_image / 255.0  # Normalization to [0, 1]
    return (normalized_image * 255).astype(np.uint8)  # Convert back to uint8 if needed

def augment_image(image):
    # Example augmentation: flipping the image horizontally
    return cv2.flip(image, 1)

def reduce_noise(image):
    return cv2.fastNlMeansDenoising(image, None, 30, 7, 21)

def enhance_contrast(image):
    return cv2.equalizeHist(image)

def extract_roi(image):
    # Example ROI extraction: using the full image
    return image

# Define your folder paths
folder_path = "H:/BIG DATA/nn_final_project/dataset/boneage-training-dataset"
output_folder = "H:/BIG DATA/nn_final_project/dataset/preprocessed-boneage-training-dataset"
desired_width = 224
desired_height = 224

# Ensure the output directory exists
os.makedirs(output_folder, exist_ok=True)

# Iterate through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith((".png", ".jpg", ".jpeg")):  # Check for image files
        # Read the image
        image_path = os.path.join(folder_path, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as grayscale

        # Step 1: Image resizing and normalization
        resized_normalized_image = resize_and_normalize(image, desired_width, desired_height)

        # Step 2: Image augmentation
        augmented_image = augment_image(resized_normalized_image)

        # Step 3: Noise reduction
        denoised_image = reduce_noise(augmented_image)

        # Step 4: Contrast enhancement
        contrast_enhanced_image = enhance_contrast(denoised_image)

        # Step 5: ROI extraction
        roi_image = extract_roi(contrast_enhanced_image)

        # Save the preprocessed image to the output folder
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, roi_image)

        print(f"Preprocessed image saved for {filename}")

print("All images have been processed and saved.")
# Out:
# Preprocessed image saved for 10000.png
# Preprocessed image saved for 10001.png
# Preprocessed image saved for 10002.png
# Preprocessed image saved for 10003.png
# Preprocessed image saved for 10004.png
# Preprocessed image saved for 10005.png
# Preprocessed image saved for 10006.png
# Preprocessed image saved for 10007.png
# Preprocessed image saved for 10008.png
# Preprocessed image saved for 10009.png
# Preprocessed image saved for 10010.png
# Preprocessed image saved for 10011.png
# Preprocessed image saved for 10012.png
# Preprocessed image saved for 10013.png
# Preprocessed image saved for 10014.png
# Preprocessed image saved for 10015.png
# Preprocessed image saved for 10016.png
# Preprocessed image saved for 10017.png
# Preprocessed image saved for 10019.png
# Preprocessed image saved for 10020.png
# Preprocessed image saved for 10021.png
# Preprocessed image saved for 10022.png
# Preprocessed image saved for 10023.png
# Preprocessed image saved for 10024.png
# Preprocessed image saved for 10025.png
# Preprocessed image saved for 10026.png
# Preprocessed image saved for 10029.png
# Preprocessed image saved for 10030.png
# Preprocessed image saved for 10031.png
# Preprocessed image saved for 10033.png
# Preprocessed image saved for 10035.png
# Preprocessed image saved for 10036.png
# Preprocessed image saved for 10037.png
# Preprocessed image saved for 10038.png
# Preprocessed image saved for 10039.png
# Preprocessed image saved for 10040.png
# Preprocessed image saved for 10041.png
# Preprocessed image saved for 10042.png
# Preprocessed image saved for 10043.png
# Preprocessed image saved for 10044.png
# Preprocessed image saved for 10045.png
# Preprocessed image saved for 10046.png
# Preprocessed image saved for 10047.png
# Preprocessed image saved for 10048.png
# Preprocessed image saved for 10049.png
# Preprocessed image saved for 10051.png
# Preprocessed image saved for 10052.png
# Preprocessed image saved for 10053.png
# Preprocessed image saved for 10054.png
# Preprocessed image saved for 10055.png
# Preprocessed image saved for 10056.png
# Preprocessed image saved for 10057.png
# Preprocessed image saved for 10058.png
# Preprocessed image saved for 10059.png
# Preprocessed image saved for 10060.png
# Preprocessed image saved for 10061.png
# Preprocessed image saved for 10062.png
# Preprocessed image saved for 10063.png
# Preprocessed image saved for 10064.png
# Preprocessed image saved for 10066.png
# Preprocessed image saved for 10067.png
# Preprocessed image saved for 10068.png
# Preprocessed image saved for 10069.png
# Preprocessed image saved for 10070.png
# Preprocessed image saved for 10071.png
# Preprocessed image saved for 10073.png
# Preprocessed image saved for 10074.png
# Preprocessed image saved for 10075.png
# Preprocessed image saved for 10076.png
# Preprocessed image saved for 10077.png
# Preprocessed image saved for 10078.png
# Preprocessed image saved for 10079.png
# Preprocessed image saved for 10080.png
# Preprocessed image saved for 10081.png
# Preprocessed image saved for 10083.png
# Preprocessed image saved for 10084.png
# Preprocessed image saved for 10085.png
# Preprocessed image saved for 10086.png
# Preprocessed image saved for 10087.png
# Preprocessed image saved for 10088.png
# Preprocessed image saved for 10089.png
# Preprocessed image saved for 10090.png
# Preprocessed image saved for 10091.png
# Preprocessed image saved for 10092.png
# Preprocessed image saved for 10093.png
# Preprocessed image saved for 10094.png
# Preprocessed image saved for 10095.png
# Preprocessed image saved for 10096.png
# Preprocessed image saved for 10097.png
# Preprocessed image saved for 10099.png
# Preprocessed image saved for 10100.png
# Preprocessed image saved for 10102.png
# Preprocessed image saved for 10103.png
# Preprocessed image saved for 10104.png
# Preprocessed image saved for 10105.png
# Preprocessed image saved for 10106.png
# Preprocessed image saved for 10107.png
# Preprocessed image saved for 10108.png
# Preprocessed image saved for 10109.png
# Preprocessed image saved for 10110.png
# Preprocessed image saved for 10111.png
# Preprocessed image saved for 10112.png
# Preprocessed image saved for 10113.png
# Preprocessed image saved for 10114.png
# Preprocessed image saved for 10115.png
# Preprocessed image saved for 10116.png
# Preprocessed image saved for 10117.png
# Preprocessed image saved for 10118.png
# Preprocessed image saved for 10120.png
# Preprocessed image saved for 10121.png
# Preprocessed image saved for 10122.png
# Preprocessed image saved for 10123.png
# Preprocessed image saved for 10125.png
# Preprocessed image saved for 10126.png
# Preprocessed image saved for 10128.png
# Preprocessed image saved for 10130.png
# Preprocessed image saved for 10131.png
# Preprocessed image saved for 10132.png
# Preprocessed image saved for 10134.png
# Preprocessed image saved for 10136.png
# Preprocessed image saved for 10137.png
# Preprocessed image saved for 10138.png
# Preprocessed image saved for 10139.png
# Preprocessed image saved for 10140.png
# Preprocessed image saved for 10141.png
# Preprocessed image saved for 10143.png
# Preprocessed image saved for 10144.png
# Preprocessed image saved for 10145.png
# Preprocessed image saved for 10146.png
# Preprocessed image saved for 10147.png
# Preprocessed image saved for 10148.png
# Preprocessed image saved for 10149.png
# Preprocessed image saved for 10150.png
# Preprocessed image saved for 10151.png
# Preprocessed image saved for 10152.png
# Preprocessed image saved for 10153.png
# Preprocessed image saved for 10154.png
# Preprocessed image saved for 10155.png
# Preprocessed image saved for 10156.png
# Preprocessed image saved for 10157.png
# Preprocessed image saved for 10158.png
# Preprocessed image saved for 10159.png
# Preprocessed image saved for 10160.png
# Preprocessed image saved for 10161.png
# Preprocessed image saved for 10163.png
# Preprocessed image saved for 10164.png
# Preprocessed image saved for 10165.png
# Preprocessed image saved for 10166.png
# Preprocessed image saved for 10168.png
# Preprocessed image saved for 10169.png
# Preprocessed image saved for 10170.png
# Preprocessed image saved for 10171.png
# Preprocessed image saved for 10174.png
# Preprocessed image saved for 10175.png
# Preprocessed image saved for 10176.png
# Preprocessed image saved for 10177.png
# Preprocessed image saved for 10178.png
# Preprocessed image saved for 10179.png
# Preprocessed image saved for 10180.png
# Preprocessed image saved for 10181.png
# Preprocessed image saved for 10182.png
# Preprocessed image saved for 10183.png
# Preprocessed image saved for 10184.png
# Preprocessed image saved for 10185.png
# Preprocessed image saved for 10186.png
# Preprocessed image saved for 10187.png
# Preprocessed image saved for 10188.png
# Preprocessed image saved for 10190.png
# Preprocessed image saved for 10192.png
# Preprocessed image saved for 10194.png
# Preprocessed image saved for 10195.png
# Preprocessed image saved for 10196.png
# Preprocessed image saved for 10197.png
# Preprocessed image saved for 10198.png
# Preprocessed image saved for 10199.png
# Preprocessed image saved for 10200.png
# Preprocessed image saved for 10201.png
# Preprocessed image saved for 10202.png
# Preprocessed image saved for 10203.png
# Preprocessed image saved for 10204.png
# Preprocessed image saved for 10205.png
# Preprocessed image saved for 10206.png
# Preprocessed image saved for 10207.png
# Preprocessed image saved for 10208.png
# Preprocessed image saved for 10209.png
# Preprocessed image saved for 10210.png
# Preprocessed image saved for 10211.png
# Preprocessed image saved for 10212.png
# Preprocessed image saved for 10214.png
# Preprocessed image saved for 10216.png
# Preprocessed image saved for 10217.png
# Preprocessed image saved for 10219.png
# Preprocessed image saved for 10220.png
# Preprocessed image saved for 10221.png
# Preprocessed image saved for 10222.png
# Preprocessed image saved for 10223.png
# Preprocessed image saved for 10224.png
# Preprocessed image saved for 10225.png
# Preprocessed image saved for 10226.png
# Preprocessed image saved for 10227.png
# Preprocessed image saved for 10228.png
# Preprocessed image saved for 10229.png
# Preprocessed image saved for 10230.png
# Preprocessed image saved for 10231.png
# Preprocessed image saved for 10232.png
# Preprocessed image saved for 10233.png
# Preprocessed image saved for 10234.png
# Preprocessed image saved for 10235.png
# Preprocessed image saved for 10236.png
# Preprocessed image saved for 10237.png
# Preprocessed image saved for 10238.png
# Preprocessed image saved for 10239.png
# Preprocessed image saved for 10240.png
# Preprocessed image saved for 10242.png
# Preprocessed image saved for 10243.png
# Preprocessed image saved for 10244.png
# Preprocessed image saved for 10245.png
# Preprocessed image saved for 10246.png
# Preprocessed image saved for 10247.png
# Preprocessed image saved for 10248.png
# Preprocessed image saved for 10249.png
# Preprocessed image saved for 10250.png
# Preprocessed image saved for 10251.png
# Preprocessed image saved for 10252.png
# Preprocessed image saved for 10253.png
# Preprocessed image saved for 10254.png
# Preprocessed image saved for 10256.png
# Preprocessed image saved for 10257.png
# Preprocessed image saved for 10258.png
# Preprocessed image saved for 10259.png
# Preprocessed image saved for 10260.png
# Preprocessed image saved for 10261.png
# Preprocessed image saved for 10262.png
# Preprocessed image saved for 10264.png
# Preprocessed image saved for 10265.png
# Preprocessed image saved for 10266.png
# Preprocessed image saved for 10267.png
# Preprocessed image saved for 10270.png
# Preprocessed image saved for 10271.png
# Preprocessed image saved for 10272.png
# Preprocessed image saved for 10273.png
# Preprocessed image saved for 10274.png
# Preprocessed image saved for 10275.png
# Preprocessed image saved for 10276.png
# Preprocessed image saved for 10277.png
# Preprocessed image saved for 10278.png
# Preprocessed image saved for 10279.png
# Preprocessed image saved for 10280.png
# Preprocessed image saved for 10281.png
# Preprocessed image saved for 10282.png
# Preprocessed image saved for 10284.png
# Preprocessed image saved for 10285.png
# Preprocessed image saved for 10286.png
# Preprocessed image saved for 10287.png
# Preprocessed image saved for 10288.png
# Preprocessed image saved for 10289.png
# Preprocessed image saved for 10290.png
# Preprocessed image saved for 10291.png
# Preprocessed image saved for 10292.png
# Preprocessed image saved for 10293.png
# Preprocessed image saved for 10294.png
# Preprocessed image saved for 10296.png
# Preprocessed image saved for 10297.png
# Preprocessed image saved for 10298.png
# Preprocessed image saved for 10299.png
# Preprocessed image saved for 10300.png
# Preprocessed image saved for 10301.png
# Preprocessed image saved for 10302.png
# Preprocessed image saved for 10303.png
# Preprocessed image saved for 10304.png
# Preprocessed image saved for 10305.png
# Preprocessed image saved for 10306.png
# Preprocessed image saved for 10307.png
# Preprocessed image saved for 10308.png
# Preprocessed image saved for 10309.png
# Preprocessed image saved for 10310.png
# Preprocessed image saved for 10311.png
# Preprocessed image saved for 10312.png
# Preprocessed image saved for 10313.png
# Preprocessed image saved for 10314.png
# Preprocessed image saved for 10315.png
# Preprocessed image saved for 10316.png
# Preprocessed image saved for 10318.png
# Preprocessed image saved for 10319.png
# Preprocessed image saved for 10320.png
# Preprocessed image saved for 10321.png
# Preprocessed image saved for 10322.png
# Preprocessed image saved for 10323.png
# Preprocessed image saved for 10324.png
# Preprocessed image saved for 10325.png
# Preprocessed image saved for 10326.png
# Preprocessed image saved for 10327.png
# Preprocessed image saved for 10328.png
# Preprocessed image saved for 10329.png
# Preprocessed image saved for 10330.png
# Preprocessed image saved for 10331.png
# Preprocessed image saved for 10332.png
# Preprocessed image saved for 10333.png
# Preprocessed image saved for 10334.png
# Preprocessed image saved for 10335.png
# Preprocessed image saved for 10336.png
# Preprocessed image saved for 10337.png
# Preprocessed image saved for 10338.png
# Preprocessed image saved for 10339.png
# Preprocessed image saved for 10340.png
# Preprocessed image saved for 10341.png
# Preprocessed image saved for 10342.png
# Preprocessed image saved for 10343.png
# Preprocessed image saved for 10345.png
# Preprocessed image saved for 10346.png
# Preprocessed image saved for 10347.png
# Preprocessed image saved for 10348.png
# Preprocessed image saved for 10351.png
# Preprocessed image saved for 10352.png
# Preprocessed image saved for 10353.png
# Preprocessed image saved for 10354.png
# Preprocessed image saved for 10356.png
# Preprocessed image saved for 10357.png
# Preprocessed image saved for 10358.png
# Preprocessed image saved for 10360.png
# Preprocessed image saved for 10361.png
# Preprocessed image saved for 10362.png
# Preprocessed image saved for 10363.png
# Preprocessed image saved for 10364.png
# Preprocessed image saved for 10366.png
# Preprocessed image saved for 10367.png
# Preprocessed image saved for 10368.png
# Preprocessed image saved for 10369.png
# Preprocessed image saved for 10370.png
# Preprocessed image saved for 10371.png
# Preprocessed image saved for 10372.png
# Preprocessed image saved for 10373.png
# Preprocessed image saved for 10374.png
# Preprocessed image saved for 10375.png
# Preprocessed image saved for 10376.png
# Preprocessed image saved for 10377.png
# Preprocessed image saved for 10378.png
# Preprocessed image saved for 10379.png
# Preprocessed image saved for 10381.png
# Preprocessed image saved for 10382.png
# Preprocessed image saved for 10383.png
# Preprocessed image saved for 10384.png
# Preprocessed image saved for 10385.png
# Preprocessed image saved for 10386.png
# Preprocessed image saved for 10387.png
# Preprocessed image saved for 10388.png
# Preprocessed image saved for 10390.png
# Preprocessed image saved for 10391.png
# Preprocessed image saved for 10392.png
# Preprocessed image saved for 10393.png
# Preprocessed image saved for 10394.png
# Preprocessed image saved for 10395.png
# Preprocessed image saved for 10396.png
# Preprocessed image saved for 10397.png
# Preprocessed image saved for 10398.png
# Preprocessed image saved for 10399.png
# Preprocessed image saved for 10400.png
# Preprocessed image saved for 10402.png
# Preprocessed image saved for 10403.png
# Preprocessed image saved for 10404.png
# Preprocessed image saved for 10405.png
# Preprocessed image saved for 10406.png
# Preprocessed image saved for 10408.png
# Preprocessed image saved for 10410.png
# Preprocessed image saved for 10411.png
# Preprocessed image saved for 10412.png
# Preprocessed image saved for 10413.png
# Preprocessed image saved for 10414.png
# Preprocessed image saved for 10415.png
# Preprocessed image saved for 10417.png
# Preprocessed image saved for 10418.png
# Preprocessed image saved for 10419.png
# Preprocessed image saved for 10420.png
# Preprocessed image saved for 10421.png
# Preprocessed image saved for 10422.png
# Preprocessed image saved for 10423.png
# Preprocessed image saved for 10424.png
# Preprocessed image saved for 10425.png
# Preprocessed image saved for 10426.png
# Preprocessed image saved for 10427.png
# Preprocessed image saved for 10428.png
# Preprocessed image saved for 10429.png
# Preprocessed image saved for 10430.png
# Preprocessed image saved for 10431.png
# Preprocessed image saved for 10433.png
# Preprocessed image saved for 10434.png
# Preprocessed image saved for 10435.png
# Preprocessed image saved for 10436.png
# Preprocessed image saved for 10437.png
# Preprocessed image saved for 10438.png
# Preprocessed image saved for 10439.png
# Preprocessed image saved for 10440.png
# Preprocessed image saved for 10441.png
# Preprocessed image saved for 10442.png
# Preprocessed image saved for 10443.png
# Preprocessed image saved for 10444.png
# Preprocessed image saved for 10446.png
# Preprocessed image saved for 10447.png
# Preprocessed image saved for 10449.png
# Preprocessed image saved for 10450.png
# Preprocessed image saved for 10451.png
# Preprocessed image saved for 10452.png
# Preprocessed image saved for 10453.png
# Preprocessed image saved for 10454.png
# Preprocessed image saved for 10455.png
# Preprocessed image saved for 10456.png
# Preprocessed image saved for 10457.png
# Preprocessed image saved for 10458.png
# Preprocessed image saved for 10459.png
# Preprocessed image saved for 10460.png
# Preprocessed image saved for 10462.png
# Preprocessed image saved for 10463.png
# Preprocessed image saved for 10464.png
# Preprocessed image saved for 10465.png
# Preprocessed image saved for 10466.png
# Preprocessed image saved for 10468.png
# Preprocessed image saved for 10469.png
# Preprocessed image saved for 10470.png
# Preprocessed image saved for 10471.png
# Preprocessed image saved for 10472.png
# Preprocessed image saved for 10474.png
# Preprocessed image saved for 10475.png
# Preprocessed image saved for 10476.png
# Preprocessed image saved for 10477.png
# Preprocessed image saved for 10478.png
# Preprocessed image saved for 10479.png
# Preprocessed image saved for 10480.png
# Preprocessed image saved for 10481.png
# Preprocessed image saved for 10482.png
# Preprocessed image saved for 10483.png
# Preprocessed image saved for 10484.png
# Preprocessed image saved for 10485.png
# Preprocessed image saved for 10486.png
# Preprocessed image saved for 10487.png
# Preprocessed image saved for 10488.png
# Preprocessed image saved for 10489.png
# Preprocessed image saved for 10490.png
# Preprocessed image saved for 10491.png
# Preprocessed image saved for 10492.png
# Preprocessed image saved for 10493.png
# Preprocessed image saved for 10494.png
# Preprocessed image saved for 10495.png
# Preprocessed image saved for 10496.png
# Preprocessed image saved for 10498.png
# Preprocessed image saved for 10499.png
# Preprocessed image saved for 10500.png
# Preprocessed image saved for 10501.png
# Preprocessed image saved for 10502.png
# Preprocessed image saved for 10503.png
# Preprocessed image saved for 10504.png
# Preprocessed image saved for 10505.png
# Preprocessed image saved for 10506.png
# Preprocessed image saved for 10508.png
# Preprocessed image saved for 10509.png
# Preprocessed image saved for 10510.png
# Preprocessed image saved for 10511.png
# Preprocessed image saved for 10512.png
# Preprocessed image saved for 10513.png
# Preprocessed image saved for 10514.png
# Preprocessed image saved for 10517.png
# Preprocessed image saved for 10518.png
# Preprocessed image saved for 10519.png
# Preprocessed image saved for 10520.png
# Preprocessed image saved for 10521.png
# Preprocessed image saved for 10522.png
# Preprocessed image saved for 10523.png
# Preprocessed image saved for 10524.png
# Preprocessed image saved for 10525.png
# Preprocessed image saved for 10526.png
# Preprocessed image saved for 10527.png
# Preprocessed image saved for 10528.png
# Preprocessed image saved for 10529.png
# Preprocessed image saved for 10530.png
# Preprocessed image saved for 10531.png
# Preprocessed image saved for 10532.png
# Preprocessed image saved for 10533.png
# Preprocessed image saved for 10534.png
# Preprocessed image saved for 10535.png
# Preprocessed image saved for 10536.png
# Preprocessed image saved for 10537.png
# Preprocessed image saved for 10538.png
# Preprocessed image saved for 10539.png
# Preprocessed image saved for 10540.png
# Preprocessed image saved for 10542.png
# Preprocessed image saved for 10544.png
# Preprocessed image saved for 10545.png
# Preprocessed image saved for 10547.png
# Preprocessed image saved for 10548.png
# Preprocessed image saved for 10550.png
# Preprocessed image saved for 10551.png
# Preprocessed image saved for 10552.png
# Preprocessed image saved for 10554.png
# Preprocessed image saved for 10555.png
# Preprocessed image saved for 10556.png
# Preprocessed image saved for 10558.png
# Preprocessed image saved for 10559.png
# Preprocessed image saved for 10561.png
# Preprocessed image saved for 10562.png
# Preprocessed image saved for 10563.png
# Preprocessed image saved for 10564.png
# Preprocessed image saved for 10566.png
# Preprocessed image saved for 10567.png
# Preprocessed image saved for 10568.png
# Preprocessed image saved for 10570.png
# Preprocessed image saved for 10571.png
# Preprocessed image saved for 10572.png
# Preprocessed image saved for 10573.png
# Preprocessed image saved for 10574.png
# Preprocessed image saved for 10575.png
# Preprocessed image saved for 10576.png
# Preprocessed image saved for 10577.png
# Preprocessed image saved for 10578.png
# Preprocessed image saved for 10579.png
# Preprocessed image saved for 10580.png
# Preprocessed image saved for 10581.png
# Preprocessed image saved for 10582.png
# Preprocessed image saved for 10583.png
# Preprocessed image saved for 10584.png
# Preprocessed image saved for 10585.png
# Preprocessed image saved for 10586.png
# Preprocessed image saved for 10588.png
# Preprocessed image saved for 10589.png
# Preprocessed image saved for 10590.png
# Preprocessed image saved for 10591.png
# Preprocessed image saved for 10592.png
# Preprocessed image saved for 10594.png
# Preprocessed image saved for 10595.png
# Preprocessed image saved for 10597.png
# Preprocessed image saved for 10598.png
# Preprocessed image saved for 10599.png
# Preprocessed image saved for 10600.png
# Preprocessed image saved for 10602.png
# Preprocessed image saved for 10603.png
# Preprocessed image saved for 10604.png
# Preprocessed image saved for 10605.png
# Preprocessed image saved for 10606.png
# Preprocessed image saved for 10607.png
# Preprocessed image saved for 10608.png
# Preprocessed image saved for 10609.png
# Preprocessed image saved for 10610.png
# Preprocessed image saved for 10612.png
# Preprocessed image saved for 10613.png
# Preprocessed image saved for 10614.png
# Preprocessed image saved for 10615.png
# Preprocessed image saved for 10616.png
# Preprocessed image saved for 10617.png
# Preprocessed image saved for 10618.png
# Preprocessed image saved for 10619.png
# Preprocessed image saved for 10621.png
# Preprocessed image saved for 10623.png
# Preprocessed image saved for 10624.png
# Preprocessed image saved for 10625.png
# Preprocessed image saved for 10626.png
# Preprocessed image saved for 10627.png
# Preprocessed image saved for 10628.png
# Preprocessed image saved for 10629.png
# Preprocessed image saved for 10631.png
# Preprocessed image saved for 10632.png
# Preprocessed image saved for 10633.png
# Preprocessed image saved for 10634.png
# Preprocessed image saved for 10635.png
# Preprocessed image saved for 10636.png
# Preprocessed image saved for 10637.png
# Preprocessed image saved for 10638.png
# Preprocessed image saved for 10639.png
# Preprocessed image saved for 10640.png
# Preprocessed image saved for 10641.png
# Preprocessed image saved for 10642.png
# Preprocessed image saved for 10643.png
# Preprocessed image saved for 10644.png
# Preprocessed image saved for 10645.png
# Preprocessed image saved for 10646.png
# Preprocessed image saved for 10647.png
# Preprocessed image saved for 10648.png
# Preprocessed image saved for 10650.png
# Preprocessed image saved for 10651.png
# Preprocessed image saved for 10652.png
# Preprocessed image saved for 10653.png
# Preprocessed image saved for 10654.png
# Preprocessed image saved for 10655.png
# Preprocessed image saved for 10656.png
# Preprocessed image saved for 10657.png
# Preprocessed image saved for 10658.png
# Preprocessed image saved for 10659.png
# Preprocessed image saved for 10660.png
# Preprocessed image saved for 10661.png
# Preprocessed image saved for 10662.png
# Preprocessed image saved for 10663.png
# Preprocessed image saved for 10664.png
# Preprocessed image saved for 10665.png
# Preprocessed image saved for 10666.png
# Preprocessed image saved for 10668.png
# Preprocessed image saved for 10669.png
# Preprocessed image saved for 10670.png
# Preprocessed image saved for 10671.png
# Preprocessed image saved for 10672.png
# Preprocessed image saved for 10673.png
# Preprocessed image saved for 10674.png
# Preprocessed image saved for 10675.png
# Preprocessed image saved for 10676.png
# Preprocessed image saved for 10677.png
# Preprocessed image saved for 10678.png
# Preprocessed image saved for 10679.png
# Preprocessed image saved for 10680.png
# Preprocessed image saved for 10681.png
# Preprocessed image saved for 10682.png
# Preprocessed image saved for 10683.png
# Preprocessed image saved for 10684.png
# Preprocessed image saved for 10685.png
# Preprocessed image saved for 10687.png
# Preprocessed image saved for 10688.png
# Preprocessed image saved for 10689.png
# Preprocessed image saved for 10690.png
# Preprocessed image saved for 10691.png
# Preprocessed image saved for 10692.png
# Preprocessed image saved for 10693.png
# Preprocessed image saved for 10694.png
# Preprocessed image saved for 10696.png
# Preprocessed image saved for 10697.png
# Preprocessed image saved for 10698.png
# Preprocessed image saved for 10699.png
# Preprocessed image saved for 10700.png
# Preprocessed image saved for 10701.png
# Preprocessed image saved for 10702.png
# Preprocessed image saved for 10704.png
# Preprocessed image saved for 10705.png
# Preprocessed image saved for 10706.png
# Preprocessed image saved for 10707.png
# Preprocessed image saved for 10708.png
# Preprocessed image saved for 10709.png
# Preprocessed image saved for 10710.png
# Preprocessed image saved for 10712.png
# Preprocessed image saved for 10713.png
# Preprocessed image saved for 10714.png
# Preprocessed image saved for 10715.png
# Preprocessed image saved for 10716.png
# Preprocessed image saved for 10717.png
# Preprocessed image saved for 10718.png
# Preprocessed image saved for 10719.png
# Preprocessed image saved for 10720.png
# Preprocessed image saved for 10721.png
# Preprocessed image saved for 10722.png
# Preprocessed image saved for 10723.png
# Preprocessed image saved for 10724.png
# Preprocessed image saved for 10725.png
# Preprocessed image saved for 10726.png
# Preprocessed image saved for 10727.png
# Preprocessed image saved for 10728.png
# Preprocessed image saved for 10729.png
# Preprocessed image saved for 10730.png
# Preprocessed image saved for 10731.png
# Preprocessed image saved for 10732.png
# Preprocessed image saved for 10733.png
# Preprocessed image saved for 10734.png
# Preprocessed image saved for 10735.png
# Preprocessed image saved for 10736.png
# Preprocessed image saved for 10737.png
# Preprocessed image saved for 10738.png
# Preprocessed image saved for 10739.png
# Preprocessed image saved for 10740.png
# Preprocessed image saved for 10741.png
# Preprocessed image saved for 10742.png
# Preprocessed image saved for 10743.png
# Preprocessed image saved for 10745.png
# Preprocessed image saved for 10746.png
# Preprocessed image saved for 10747.png
# Preprocessed image saved for 10748.png
# Preprocessed image saved for 10749.png
# Preprocessed image saved for 10750.png
# Preprocessed image saved for 10751.png
# Preprocessed image saved for 10753.png
# Preprocessed image saved for 10754.png
# Preprocessed image saved for 10755.png
# Preprocessed image saved for 10756.png
# Preprocessed image saved for 10757.png
# Preprocessed image saved for 10758.png
# Preprocessed image saved for 10759.png
# Preprocessed image saved for 10760.png
# Preprocessed image saved for 10761.png
# Preprocessed image saved for 10762.png
# Preprocessed image saved for 10763.png
# Preprocessed image saved for 10764.png
# Preprocessed image saved for 10765.png
# Preprocessed image saved for 10766.png
# Preprocessed image saved for 10767.png
# Preprocessed image saved for 10768.png
# Preprocessed image saved for 10769.png
# Preprocessed image saved for 10771.png
# Preprocessed image saved for 10773.png
# Preprocessed image saved for 10774.png
# Preprocessed image saved for 10775.png
# Preprocessed image saved for 10776.png
# Preprocessed image saved for 10777.png
# Preprocessed image saved for 10779.png
# Preprocessed image saved for 10780.png
# Preprocessed image saved for 10781.png
# Preprocessed image saved for 10782.png
# Preprocessed image saved for 10783.png
# Preprocessed image saved for 10784.png
# Preprocessed image saved for 10785.png
# Preprocessed image saved for 10786.png
# Preprocessed image saved for 10787.png
# Preprocessed image saved for 10788.png
# Preprocessed image saved for 10789.png
# Preprocessed image saved for 10790.png
# Preprocessed image saved for 10791.png
# Preprocessed image saved for 10793.png
# Preprocessed image saved for 10794.png
# Preprocessed image saved for 10796.png
# Preprocessed image saved for 10797.png
# Preprocessed image saved for 10798.png
# Preprocessed image saved for 10799.png
# Preprocessed image saved for 10800.png
# Preprocessed image saved for 10801.png
# Preprocessed image saved for 10802.png
# Preprocessed image saved for 10803.png
# Preprocessed image saved for 10806.png
# Preprocessed image saved for 10807.png
# Preprocessed image saved for 10809.png
# Preprocessed image saved for 10810.png
# Preprocessed image saved for 10811.png
# Preprocessed image saved for 10812.png
# Preprocessed image saved for 10813.png
# Preprocessed image saved for 10814.png
# Preprocessed image saved for 10815.png
# Preprocessed image saved for 10816.png
# Preprocessed image saved for 10818.png
# Preprocessed image saved for 10819.png
# Preprocessed image saved for 10820.png
# Preprocessed image saved for 10821.png
# Preprocessed image saved for 10823.png
# Preprocessed image saved for 10824.png
# Preprocessed image saved for 10825.png
# Preprocessed image saved for 10826.png
# Preprocessed image saved for 10827.png
# Preprocessed image saved for 10828.png
# Preprocessed image saved for 10829.png
# Preprocessed image saved for 10830.png
# Preprocessed image saved for 10831.png
# Preprocessed image saved for 10833.png
# Preprocessed image saved for 10834.png
# Preprocessed image saved for 10835.png
# Preprocessed image saved for 10836.png
# Preprocessed image saved for 10837.png
# Preprocessed image saved for 10838.png
# Preprocessed image saved for 10839.png
# Preprocessed image saved for 10841.png
# Preprocessed image saved for 10842.png
# Preprocessed image saved for 10843.png
# Preprocessed image saved for 10844.png
# Preprocessed image saved for 10845.png
# Preprocessed image saved for 10846.png
# Preprocessed image saved for 10847.png
# Preprocessed image saved for 10848.png
# Preprocessed image saved for 10849.png
# Preprocessed image saved for 10850.png
# Preprocessed image saved for 10851.png
# Preprocessed image saved for 10852.png
# Preprocessed image saved for 10853.png
# Preprocessed image saved for 10854.png
# Preprocessed image saved for 10855.png
# Preprocessed image saved for 10856.png
# Preprocessed image saved for 10857.png
# Preprocessed image saved for 10858.png
# Preprocessed image saved for 10859.png
# Preprocessed image saved for 10860.png
# Preprocessed image saved for 10861.png
# Preprocessed image saved for 10862.png
# Preprocessed image saved for 10863.png
# Preprocessed image saved for 10864.png
# Preprocessed image saved for 10865.png
# Preprocessed image saved for 10866.png
# Preprocessed image saved for 10867.png
# Preprocessed image saved for 10868.png
# Preprocessed image saved for 10869.png
# Preprocessed image saved for 10870.png
# Preprocessed image saved for 10871.png
# Preprocessed image saved for 10872.png
# Preprocessed image saved for 10873.png
# Preprocessed image saved for 10874.png
# Preprocessed image saved for 10875.png
# Preprocessed image saved for 10876.png
# Preprocessed image saved for 10877.png
# Preprocessed image saved for 10878.png
# Preprocessed image saved for 10879.png
# Preprocessed image saved for 10880.png
# Preprocessed image saved for 10881.png
# Preprocessed image saved for 10882.png
# Preprocessed image saved for 10883.png
# Preprocessed image saved for 10884.png
# Preprocessed image saved for 10885.png
# Preprocessed image saved for 10886.png
# Preprocessed image saved for 10887.png
# Preprocessed image saved for 10888.png
# Preprocessed image saved for 10889.png
# Preprocessed image saved for 10890.png
# Preprocessed image saved for 10891.png
# Preprocessed image saved for 10892.png
# Preprocessed image saved for 10893.png
# Preprocessed image saved for 10894.png
# Preprocessed image saved for 10895.png
# Preprocessed image saved for 10896.png
# Preprocessed image saved for 10897.png
# Preprocessed image saved for 10898.png
# Preprocessed image saved for 10899.png
# Preprocessed image saved for 10900.png
# Preprocessed image saved for 10901.png
# Preprocessed image saved for 10902.png
# Preprocessed image saved for 10903.png
# Preprocessed image saved for 10904.png
# Preprocessed image saved for 10905.png
# Preprocessed image saved for 10906.png
# Preprocessed image saved for 10907.png
# Preprocessed image saved for 10908.png
# Preprocessed image saved for 10909.png
# Preprocessed image saved for 10910.png
# Preprocessed image saved for 10911.png
# Preprocessed image saved for 10912.png
# Preprocessed image saved for 10913.png
# Preprocessed image saved for 10914.png
# Preprocessed image saved for 10915.png
# Preprocessed image saved for 10916.png
# Preprocessed image saved for 10917.png
# Preprocessed image saved for 10918.png
# Preprocessed image saved for 10919.png
# Preprocessed image saved for 10920.png
# Preprocessed image saved for 10922.png
# Preprocessed image saved for 10925.png
# Preprocessed image saved for 10926.png
# Preprocessed image saved for 10927.png
# Preprocessed image saved for 10928.png
# Preprocessed image saved for 10929.png
# Preprocessed image saved for 10930.png
# Preprocessed image saved for 10931.png
# Preprocessed image saved for 10932.png
# Preprocessed image saved for 10933.png
# Preprocessed image saved for 10935.png
# Preprocessed image saved for 10936.png
# Preprocessed image saved for 10937.png
# Preprocessed image saved for 10939.png
# Preprocessed image saved for 10940.png
# Preprocessed image saved for 10941.png
# Preprocessed image saved for 10942.png
# Preprocessed image saved for 10943.png
# Preprocessed image saved for 10944.png
# Preprocessed image saved for 10945.png
# Preprocessed image saved for 10946.png
# Preprocessed image saved for 10947.png
# Preprocessed image saved for 10948.png
# Preprocessed image saved for 10949.png
# Preprocessed image saved for 10950.png
# Preprocessed image saved for 10951.png
# Preprocessed image saved for 10952.png
# Preprocessed image saved for 10953.png
# Preprocessed image saved for 10954.png
# Preprocessed image saved for 10955.png
# Preprocessed image saved for 10956.png
# Preprocessed image saved for 10957.png
# Preprocessed image saved for 10960.png
# Preprocessed image saved for 10961.png
# Preprocessed image saved for 10962.png
# Preprocessed image saved for 10963.png
# Preprocessed image saved for 10964.png
# Preprocessed image saved for 10965.png
# Preprocessed image saved for 10967.png
# Preprocessed image saved for 10968.png
# Preprocessed image saved for 10969.png
# Preprocessed image saved for 10970.png
# Preprocessed image saved for 10971.png
# Preprocessed image saved for 10972.png
# Preprocessed image saved for 10973.png
# Preprocessed image saved for 10974.png
# Preprocessed image saved for 10975.png
# Preprocessed image saved for 10976.png
# Preprocessed image saved for 10977.png
# Preprocessed image saved for 10978.png
# Preprocessed image saved for 10979.png
# Preprocessed image saved for 10980.png
# Preprocessed image saved for 10981.png
# Preprocessed image saved for 10982.png
# Preprocessed image saved for 10985.png
# Preprocessed image saved for 10986.png
# Preprocessed image saved for 10987.png
# Preprocessed image saved for 10988.png
# Preprocessed image saved for 10989.png
# Preprocessed image saved for 10990.png
# Preprocessed image saved for 10992.png
# Preprocessed image saved for 10993.png
# Preprocessed image saved for 10994.png
# Preprocessed image saved for 10995.png
# Preprocessed image saved for 10996.png
# Preprocessed image saved for 10997.png
# Preprocessed image saved for 10998.png
# Preprocessed image saved for 10999.png
# Preprocessed image saved for 11000.png
# Preprocessed image saved for 11001.png
# Preprocessed image saved for 11002.png
# Preprocessed image saved for 11003.png
# Preprocessed image saved for 11004.png
# Preprocessed image saved for 11005.png
# Preprocessed image saved for 11006.png
# Preprocessed image saved for 11007.png
# Preprocessed image saved for 11008.png
# Preprocessed image saved for 11010.png
# Preprocessed image saved for 11011.png
# Preprocessed image saved for 11012.png
# Preprocessed image saved for 11013.png
# Preprocessed image saved for 11014.png
# Preprocessed image saved for 11015.png
# Preprocessed image saved for 11016.png
# Preprocessed image saved for 11018.png
# Preprocessed image saved for 11019.png
# Preprocessed image saved for 11020.png
# Preprocessed image saved for 11021.png
# Preprocessed image saved for 11022.png
# Preprocessed image saved for 11023.png
# Preprocessed image saved for 11024.png
# Preprocessed image saved for 11025.png
# Preprocessed image saved for 11026.png
# Preprocessed image saved for 11027.png
# Preprocessed image saved for 11029.png
# Preprocessed image saved for 11032.png
# Preprocessed image saved for 11033.png
# Preprocessed image saved for 11034.png
# Preprocessed image saved for 11035.png
# Preprocessed image saved for 11036.png
# Preprocessed image saved for 11037.png
# Preprocessed image saved for 11038.png
# Preprocessed image saved for 11040.png
# Preprocessed image saved for 11041.png
# Preprocessed image saved for 11042.png
# Preprocessed image saved for 11043.png
# Preprocessed image saved for 11044.png
# Preprocessed image saved for 11045.png
# Preprocessed image saved for 11046.png
# Preprocessed image saved for 11048.png
# Preprocessed image saved for 11049.png
# Preprocessed image saved for 11050.png
# Preprocessed image saved for 11051.png
# Preprocessed image saved for 11052.png
# Preprocessed image saved for 11053.png
# Preprocessed image saved for 11054.png
# Preprocessed image saved for 11055.png
# Preprocessed image saved for 11056.png
# Preprocessed image saved for 11057.png
# Preprocessed image saved for 11058.png
# Preprocessed image saved for 11059.png
# Preprocessed image saved for 11060.png
# Preprocessed image saved for 11061.png
# Preprocessed image saved for 11062.png
# Preprocessed image saved for 11063.png
# Preprocessed image saved for 11064.png
# Preprocessed image saved for 11065.png
# Preprocessed image saved for 11066.png
# Preprocessed image saved for 11068.png
# Preprocessed image saved for 11070.png
# Preprocessed image saved for 11071.png
# Preprocessed image saved for 11072.png
# Preprocessed image saved for 11073.png
# Preprocessed image saved for 11074.png
# Preprocessed image saved for 11075.png
# Preprocessed image saved for 11077.png
# Preprocessed image saved for 11078.png
# Preprocessed image saved for 11079.png
# Preprocessed image saved for 11080.png
# Preprocessed image saved for 11081.png
# Preprocessed image saved for 11082.png
# Preprocessed image saved for 11084.png
# Preprocessed image saved for 11085.png
# Preprocessed image saved for 11086.png
# Preprocessed image saved for 11087.png
# Preprocessed image saved for 11088.png
# Preprocessed image saved for 11089.png
# Preprocessed image saved for 11091.png
# Preprocessed image saved for 11092.png
# Preprocessed image saved for 11093.png
# Preprocessed image saved for 11094.png
# Preprocessed image saved for 11095.png
# Preprocessed image saved for 11096.png
# Preprocessed image saved for 11097.png
# Preprocessed image saved for 11098.png
# Preprocessed image saved for 11099.png
# Preprocessed image saved for 11100.png
# Preprocessed image saved for 11101.png
# Preprocessed image saved for 11102.png
# Preprocessed image saved for 11103.png
# Preprocessed image saved for 11104.png
# Preprocessed image saved for 11105.png
# Preprocessed image saved for 11106.png
# Preprocessed image saved for 11107.png
# Preprocessed image saved for 11108.png
# Preprocessed image saved for 11110.png
# Preprocessed image saved for 11111.png
# Preprocessed image saved for 11112.png
# Preprocessed image saved for 11113.png
# Preprocessed image saved for 11114.png
# Preprocessed image saved for 11115.png
# Preprocessed image saved for 11116.png
# Preprocessed image saved for 11117.png
# Preprocessed image saved for 11118.png
# Preprocessed image saved for 11119.png
# Preprocessed image saved for 11120.png
# Preprocessed image saved for 11121.png
# Preprocessed image saved for 11123.png
# Preprocessed image saved for 11124.png
# Preprocessed image saved for 11126.png
# Preprocessed image saved for 11127.png
# Preprocessed image saved for 11128.png
# Preprocessed image saved for 11129.png
# Preprocessed image saved for 11130.png
# Preprocessed image saved for 11132.png
# Preprocessed image saved for 11133.png
# Preprocessed image saved for 11134.png
# Preprocessed image saved for 11135.png
# Preprocessed image saved for 11137.png
# Preprocessed image saved for 11138.png
# Preprocessed image saved for 11139.png
# Preprocessed image saved for 11141.png
# Preprocessed image saved for 11142.png
# Preprocessed image saved for 11143.png
# Preprocessed image saved for 11144.png
# Preprocessed image saved for 11145.png
# Preprocessed image saved for 11147.png
# Preprocessed image saved for 11148.png
# Preprocessed image saved for 11149.png
# Preprocessed image saved for 11150.png
# Preprocessed image saved for 11151.png
# Preprocessed image saved for 11152.png
# Preprocessed image saved for 11153.png
# Preprocessed image saved for 11154.png
# Preprocessed image saved for 11155.png
# Preprocessed image saved for 11157.png
# Preprocessed image saved for 11158.png
# Preprocessed image saved for 11159.png
# Preprocessed image saved for 11160.png
# Preprocessed image saved for 11162.png
# Preprocessed image saved for 11163.png
# Preprocessed image saved for 11164.png
# Preprocessed image saved for 11165.png
# Preprocessed image saved for 11166.png
# Preprocessed image saved for 11167.png
# Preprocessed image saved for 11168.png
# Preprocessed image saved for 11169.png
# Preprocessed image saved for 11170.png
# Preprocessed image saved for 11171.png
# Preprocessed image saved for 11172.png
# Preprocessed image saved for 11173.png
# Preprocessed image saved for 11174.png
# Preprocessed image saved for 11175.png
# Preprocessed image saved for 11176.png
# Preprocessed image saved for 11177.png
# Preprocessed image saved for 11179.png
# Preprocessed image saved for 11180.png
# Preprocessed image saved for 11181.png
# Preprocessed image saved for 11182.png
# Preprocessed image saved for 11184.png
# Preprocessed image saved for 11185.png
# Preprocessed image saved for 11186.png
# Preprocessed image saved for 11187.png
# Preprocessed image saved for 11189.png
# Preprocessed image saved for 11190.png
# Preprocessed image saved for 11191.png
# Preprocessed image saved for 11192.png
# Preprocessed image saved for 11193.png
# Preprocessed image saved for 11194.png
# Preprocessed image saved for 11195.png
# Preprocessed image saved for 11196.png
# Preprocessed image saved for 11197.png
# Preprocessed image saved for 11198.png
# Preprocessed image saved for 11199.png
# Preprocessed image saved for 11200.png
# Preprocessed image saved for 11201.png
# Preprocessed image saved for 11202.png
# Preprocessed image saved for 11203.png
# Preprocessed image saved for 11204.png
# Preprocessed image saved for 11205.png
# Preprocessed image saved for 11206.png
# Preprocessed image saved for 11207.png
# Preprocessed image saved for 11208.png
# Preprocessed image saved for 11209.png
# Preprocessed image saved for 11210.png
# Preprocessed image saved for 11211.png
# Preprocessed image saved for 11212.png
# Preprocessed image saved for 11213.png
# Preprocessed image saved for 11214.png
# Preprocessed image saved for 11215.png
# Preprocessed image saved for 11216.png
# Preprocessed image saved for 11217.png
# Preprocessed image saved for 11219.png
# Preprocessed image saved for 11220.png
# Preprocessed image saved for 11222.png
# Preprocessed image saved for 11223.png
# Preprocessed image saved for 11224.png
# Preprocessed image saved for 11225.png
# Preprocessed image saved for 11226.png
# Preprocessed image saved for 11227.png
# Preprocessed image saved for 11229.png
# Preprocessed image saved for 11230.png
# Preprocessed image saved for 11231.png
# Preprocessed image saved for 11232.png
# Preprocessed image saved for 11233.png
# Preprocessed image saved for 11234.png
# Preprocessed image saved for 11235.png
# Preprocessed image saved for 11236.png
# Preprocessed image saved for 11237.png
# Preprocessed image saved for 11239.png
# Preprocessed image saved for 11240.png
# Preprocessed image saved for 11241.png
# Preprocessed image saved for 11242.png
# Preprocessed image saved for 11243.png
# Preprocessed image saved for 11244.png
# Preprocessed image saved for 11245.png
# Preprocessed image saved for 11246.png
# Preprocessed image saved for 11247.png
# Preprocessed image saved for 11248.png
# Preprocessed image saved for 11249.png
# Preprocessed image saved for 11250.png
# Preprocessed image saved for 11252.png
# Preprocessed image saved for 11253.png
# Preprocessed image saved for 11254.png
# Preprocessed image saved for 11255.png
# Preprocessed image saved for 11256.png
# Preprocessed image saved for 11257.png
# Preprocessed image saved for 11258.png
# Preprocessed image saved for 11259.png
# Preprocessed image saved for 11261.png
# Preprocessed image saved for 11262.png
# Preprocessed image saved for 11263.png
# Preprocessed image saved for 11264.png
# Preprocessed image saved for 11265.png
# Preprocessed image saved for 11266.png
# Preprocessed image saved for 11267.png
# Preprocessed image saved for 11268.png
# Preprocessed image saved for 11269.png
# Preprocessed image saved for 11273.png
# Preprocessed image saved for 11275.png
# Preprocessed image saved for 11276.png
# Preprocessed image saved for 11277.png
# Preprocessed image saved for 11278.png
# Preprocessed image saved for 11279.png
# Preprocessed image saved for 11280.png
# Preprocessed image saved for 11281.png
# Preprocessed image saved for 11283.png
# Preprocessed image saved for 11285.png
# Preprocessed image saved for 11286.png
# Preprocessed image saved for 11287.png
# Preprocessed image saved for 11289.png
# Preprocessed image saved for 11290.png
# Preprocessed image saved for 11291.png
# Preprocessed image saved for 11292.png
# Preprocessed image saved for 11293.png
# Preprocessed image saved for 11294.png
# Preprocessed image saved for 11295.png
# Preprocessed image saved for 11298.png
# Preprocessed image saved for 11299.png
# Preprocessed image saved for 11300.png
# Preprocessed image saved for 11301.png
# Preprocessed image saved for 11302.png
# Preprocessed image saved for 11303.png
# Preprocessed image saved for 11304.png
# Preprocessed image saved for 11305.png
# Preprocessed image saved for 11306.png
# Preprocessed image saved for 11307.png
# Preprocessed image saved for 11308.png
# Preprocessed image saved for 11309.png
# Preprocessed image saved for 11310.png
# Preprocessed image saved for 11311.png
# Preprocessed image saved for 11313.png
# Preprocessed image saved for 11314.png
# Preprocessed image saved for 11315.png
# Preprocessed image saved for 11316.png
# Preprocessed image saved for 11317.png
# Preprocessed image saved for 11318.png
# Preprocessed image saved for 11319.png
# Preprocessed image saved for 11320.png
# Preprocessed image saved for 11321.png
# Preprocessed image saved for 11322.png
# Preprocessed image saved for 11323.png
# Preprocessed image saved for 11324.png
# Preprocessed image saved for 11326.png
# Preprocessed image saved for 11327.png
# Preprocessed image saved for 11328.png
# Preprocessed image saved for 11329.png
# Preprocessed image saved for 11330.png
# Preprocessed image saved for 11331.png
# Preprocessed image saved for 11332.png
# Preprocessed image saved for 11334.png
# Preprocessed image saved for 11336.png
# Preprocessed image saved for 11338.png
# Preprocessed image saved for 11339.png
# Preprocessed image saved for 11340.png
# Preprocessed image saved for 11341.png
# Preprocessed image saved for 11342.png
# Preprocessed image saved for 11343.png
# Preprocessed image saved for 11344.png
# Preprocessed image saved for 11345.png
# Preprocessed image saved for 11346.png
# Preprocessed image saved for 11347.png
# Preprocessed image saved for 11348.png
# Preprocessed image saved for 11349.png
# Preprocessed image saved for 11351.png
# Preprocessed image saved for 11352.png
# Preprocessed image saved for 11353.png
# Preprocessed image saved for 11354.png
# Preprocessed image saved for 11355.png
# Preprocessed image saved for 11356.png
# Preprocessed image saved for 11358.png
# Preprocessed image saved for 11360.png
# Preprocessed image saved for 11361.png
# Preprocessed image saved for 11362.png
# Preprocessed image saved for 11363.png
# Preprocessed image saved for 11364.png
# Preprocessed image saved for 11365.png
# Preprocessed image saved for 11366.png
# Preprocessed image saved for 11367.png
# Preprocessed image saved for 11368.png
# Preprocessed image saved for 11369.png
# Preprocessed image saved for 11371.png
# Preprocessed image saved for 11372.png
# Preprocessed image saved for 11373.png
# Preprocessed image saved for 11374.png
# Preprocessed image saved for 11375.png
# Preprocessed image saved for 11376.png
# Preprocessed image saved for 11377.png
# Preprocessed image saved for 11378.png
# Preprocessed image saved for 11379.png
# Preprocessed image saved for 11380.png
# Preprocessed image saved for 11381.png
# Preprocessed image saved for 11382.png
# Preprocessed image saved for 11383.png
# ...
# Preprocessed image saved for 12518.png
# Preprocessed image saved for 12519.png
# Preprocessed image saved for 12520.png
# Preprocessed image saved for 12521.png
# Preprocessed image saved for 12522.png
# Preprocessed image saved for 12523.png
# Preprocessed image saved for 12524.png
# Preprocessed image saved for 12525.png
# Preprocessed image saved for 12527.png
# Preprocessed image saved for 12528.png
# Preprocessed image saved for 12529.png
# Preprocessed image saved for 12530.png
# Preprocessed image saved for 12531.png
# Preprocessed image saved for 12532.png
# Preprocessed image saved for 12533.png
# Preprocessed image saved for 12534.png
# Preprocessed image saved for 12535.png
# Preprocessed image saved for 12536.png
# Preprocessed image saved for 12537.png
# Preprocessed image saved for 12538.png
# Preprocessed image saved for 12539.png
# Preprocessed image saved for 12540.png
# Preprocessed image saved for 12541.png
# Preprocessed image saved for 12542.png
# Preprocessed image saved for 12543.png
# Preprocessed image saved for 12544.png
# Preprocessed image saved for 12545.png
# Preprocessed image saved for 12546.png
# Preprocessed image saved for 12547.png
# Preprocessed image saved for 12548.png
# Preprocessed image saved for 12549.png
# Preprocessed image saved for 12550.png
# Preprocessed image saved for 12551.png
# Preprocessed image saved for 12552.png
# Preprocessed image saved for 12553.png
# Preprocessed image saved for 12554.png
# Preprocessed image saved for 12555.png
# Preprocessed image saved for 12556.png
# Preprocessed image saved for 12557.png
# Preprocessed image saved for 12558.png
# Preprocessed image saved for 12559.png
# Preprocessed image saved for 12560.png
# Preprocessed image saved for 12561.png
# Preprocessed image saved for 12562.png
# Preprocessed image saved for 12563.png
# Preprocessed image saved for 12564.png
# Preprocessed image saved for 12565.png
# Preprocessed image saved for 12566.png
# Preprocessed image saved for 12567.png
# Preprocessed image saved for 12568.png
# Preprocessed image saved for 12569.png
# Preprocessed image saved for 12570.png
# Preprocessed image saved for 12571.png
# Preprocessed image saved for 12572.png
# Preprocessed image saved for 12573.png
# Preprocessed image saved for 12574.png
# Preprocessed image saved for 12575.png
# Preprocessed image saved for 12576.png
# Preprocessed image saved for 12577.png
# Preprocessed image saved for 12578.png
# Preprocessed image saved for 12579.png
# Preprocessed image saved for 12580.png
# Preprocessed image saved for 12581.png
# Preprocessed image saved for 12582.png
# Preprocessed image saved for 12583.png
# Preprocessed image saved for 12584.png
# Preprocessed image saved for 12585.png
# Preprocessed image saved for 12586.png
# Preprocessed image saved for 12587.png
# Preprocessed image saved for 12588.png
# Preprocessed image saved for 12589.png
# Preprocessed image saved for 12591.png
# Preprocessed image saved for 12592.png
# Preprocessed image saved for 12593.png
# Preprocessed image saved for 12594.png
# Preprocessed image saved for 12595.png
# Preprocessed image saved for 12596.png
# Preprocessed image saved for 12597.png
# Preprocessed image saved for 12598.png
# Preprocessed image saved for 12599.png
# Preprocessed image saved for 12600.png
# Preprocessed image saved for 12601.png
# Preprocessed image saved for 12602.png
# Preprocessed image saved for 12603.png
# Preprocessed image saved for 12604.png
# Preprocessed image saved for 12607.png
# Preprocessed image saved for 12608.png
# Preprocessed image saved for 12609.png
# Preprocessed image saved for 12610.png
# Preprocessed image saved for 12611.png
# Preprocessed image saved for 12612.png
# Preprocessed image saved for 12613.png
# Preprocessed image saved for 12614.png
# Preprocessed image saved for 12615.png
# Preprocessed image saved for 12616.png
# Preprocessed image saved for 12617.png
# Preprocessed image saved for 12618.png
# Preprocessed image saved for 12619.png
# Preprocessed image saved for 12620.png
# Preprocessed image saved for 12621.png
# Preprocessed image saved for 12622.png
# Preprocessed image saved for 12623.png
# Preprocessed image saved for 12624.png
# Preprocessed image saved for 12625.png
# Preprocessed image saved for 12626.png
# Preprocessed image saved for 12627.png
# Preprocessed image saved for 12628.png
# Preprocessed image saved for 12629.png
# Preprocessed image saved for 12630.png
# Preprocessed image saved for 12631.png
# Preprocessed image saved for 12632.png
# Preprocessed image saved for 12633.png
# Preprocessed image saved for 12635.png
# Preprocessed image saved for 12636.png
# Preprocessed image saved for 12638.png
# Preprocessed image saved for 12639.png
# Preprocessed image saved for 12640.png
# Preprocessed image saved for 12641.png
# Preprocessed image saved for 12642.png
# Preprocessed image saved for 12643.png
# Preprocessed image saved for 12646.png
# Preprocessed image saved for 12647.png
# Preprocessed image saved for 12648.png
# Preprocessed image saved for 12649.png
# Preprocessed image saved for 12650.png
# Preprocessed image saved for 12651.png
# Preprocessed image saved for 12652.png
# Preprocessed image saved for 12654.png
# Preprocessed image saved for 12655.png
# Preprocessed image saved for 12656.png
# Preprocessed image saved for 12657.png
# Preprocessed image saved for 12658.png
# Preprocessed image saved for 12659.png
# Preprocessed image saved for 12660.png
# Preprocessed image saved for 12662.png
# Preprocessed image saved for 12663.png
# Preprocessed image saved for 12664.png
# Preprocessed image saved for 12665.png
# Preprocessed image saved for 12666.png
# Preprocessed image saved for 12667.png
# Preprocessed image saved for 12668.png
# Preprocessed image saved for 12669.png
# Preprocessed image saved for 12670.png
# Preprocessed image saved for 12671.png
# Preprocessed image saved for 12672.png
# Preprocessed image saved for 12673.png
# Preprocessed image saved for 12675.png
# Preprocessed image saved for 12676.png
# Preprocessed image saved for 12677.png
# Preprocessed image saved for 12678.png
# Preprocessed image saved for 12680.png
# Preprocessed image saved for 12681.png
# Preprocessed image saved for 12682.png
# Preprocessed image saved for 12683.png
# Preprocessed image saved for 12684.png
# Preprocessed image saved for 12685.png
# Preprocessed image saved for 12686.png
# Preprocessed image saved for 12687.png
# Preprocessed image saved for 12688.png
# Preprocessed image saved for 12689.png
# Preprocessed image saved for 12690.png
# Preprocessed image saved for 12691.png
# Preprocessed image saved for 12692.png
# Preprocessed image saved for 12693.png
# Preprocessed image saved for 12694.png
# Preprocessed image saved for 12696.png
# Preprocessed image saved for 12697.png
# Preprocessed image saved for 12698.png
# Preprocessed image saved for 12699.png
# Preprocessed image saved for 12700.png
# Preprocessed image saved for 12701.png
# Preprocessed image saved for 12702.png
# Preprocessed image saved for 12703.png
# Preprocessed image saved for 12704.png
# Preprocessed image saved for 12705.png
# Preprocessed image saved for 12706.png
# Preprocessed image saved for 12707.png
# Preprocessed image saved for 12709.png
# Preprocessed image saved for 12710.png
# Preprocessed image saved for 12711.png
# Preprocessed image saved for 12712.png
# Preprocessed image saved for 12713.png
# Preprocessed image saved for 12714.png
# Preprocessed image saved for 12715.png
# Preprocessed image saved for 12716.png
# Preprocessed image saved for 12717.png
# Preprocessed image saved for 12718.png
# Preprocessed image saved for 12719.png
# Preprocessed image saved for 12720.png
# Preprocessed image saved for 12721.png
# Preprocessed image saved for 12722.png
# Preprocessed image saved for 12723.png
# Preprocessed image saved for 12724.png
# Preprocessed image saved for 12726.png
# Preprocessed image saved for 12727.png
# Preprocessed image saved for 12728.png
# Preprocessed image saved for 12729.png
# Preprocessed image saved for 12730.png
# Preprocessed image saved for 12731.png
# Preprocessed image saved for 12732.png
# Preprocessed image saved for 12733.png
# Preprocessed image saved for 12734.png
# Preprocessed image saved for 12735.png
# Preprocessed image saved for 12736.png
# Preprocessed image saved for 12737.png
# Preprocessed image saved for 12738.png
# Preprocessed image saved for 12739.png
# Preprocessed image saved for 12740.png
# Preprocessed image saved for 12741.png
# Preprocessed image saved for 12742.png
# Preprocessed image saved for 12743.png
# Preprocessed image saved for 12744.png
# Preprocessed image saved for 12745.png
# Preprocessed image saved for 12746.png
# Preprocessed image saved for 12747.png
# Preprocessed image saved for 12749.png
# Preprocessed image saved for 12750.png
# Preprocessed image saved for 12751.png
# Preprocessed image saved for 12752.png
# Preprocessed image saved for 12753.png
# Preprocessed image saved for 12754.png
# Preprocessed image saved for 12755.png
# Preprocessed image saved for 12756.png
# Preprocessed image saved for 12757.png
# Preprocessed image saved for 12758.png
# Preprocessed image saved for 12759.png
# Preprocessed image saved for 12760.png
# Preprocessed image saved for 12761.png
# Preprocessed image saved for 12762.png
# Preprocessed image saved for 12763.png
# Preprocessed image saved for 12764.png
# Preprocessed image saved for 12765.png
# Preprocessed image saved for 12766.png
# Preprocessed image saved for 12767.png
# Preprocessed image saved for 12768.png
# Preprocessed image saved for 12769.png
# Preprocessed image saved for 12770.png
# Preprocessed image saved for 12771.png
# Preprocessed image saved for 12772.png
# Preprocessed image saved for 12774.png
# Preprocessed image saved for 12775.png
# Preprocessed image saved for 12776.png
# Preprocessed image saved for 12777.png
# Preprocessed image saved for 12778.png
# Preprocessed image saved for 12779.png
# Preprocessed image saved for 12780.png
# Preprocessed image saved for 12781.png
# Preprocessed image saved for 12782.png
# Preprocessed image saved for 12784.png
# Preprocessed image saved for 12786.png
# Preprocessed image saved for 12787.png
# Preprocessed image saved for 12788.png
# Preprocessed image saved for 12789.png
# Preprocessed image saved for 12791.png
# Preprocessed image saved for 12793.png
# Preprocessed image saved for 12794.png
# Preprocessed image saved for 12795.png
# Preprocessed image saved for 12796.png
# Preprocessed image saved for 12797.png
# Preprocessed image saved for 12798.png
# Preprocessed image saved for 12799.png
# Preprocessed image saved for 12800.png
# Preprocessed image saved for 12802.png
# Preprocessed image saved for 12803.png
# Preprocessed image saved for 12804.png
# Preprocessed image saved for 12805.png
# Preprocessed image saved for 12807.png
# Preprocessed image saved for 12808.png
# Preprocessed image saved for 12809.png
# Preprocessed image saved for 12810.png
# Preprocessed image saved for 12811.png
# Preprocessed image saved for 12812.png
# Preprocessed image saved for 12813.png
# Preprocessed image saved for 12816.png
# Preprocessed image saved for 12817.png
# Preprocessed image saved for 12818.png
# Preprocessed image saved for 12819.png
# Preprocessed image saved for 12820.png
# Preprocessed image saved for 12821.png
# Preprocessed image saved for 12822.png
# Preprocessed image saved for 12824.png
# Preprocessed image saved for 12825.png
# Preprocessed image saved for 12826.png
# Preprocessed image saved for 12827.png
# Preprocessed image saved for 12828.png
# Preprocessed image saved for 12829.png
# Preprocessed image saved for 12830.png
# Preprocessed image saved for 12831.png
# Preprocessed image saved for 12832.png
# Preprocessed image saved for 12833.png
# Preprocessed image saved for 12834.png
# Preprocessed image saved for 12835.png
# Preprocessed image saved for 12836.png
# Preprocessed image saved for 12837.png
# Preprocessed image saved for 12838.png
# Preprocessed image saved for 12840.png
# Preprocessed image saved for 12841.png
# Preprocessed image saved for 12842.png
# Preprocessed image saved for 12845.png
# Preprocessed image saved for 12846.png
# Preprocessed image saved for 12847.png
# Preprocessed image saved for 12848.png
# Preprocessed image saved for 12849.png
# Preprocessed image saved for 12850.png
# Preprocessed image saved for 12852.png
# Preprocessed image saved for 12853.png
# Preprocessed image saved for 12854.png
# Preprocessed image saved for 12855.png
# Preprocessed image saved for 12856.png
# Preprocessed image saved for 12857.png
# Preprocessed image saved for 12859.png
# Preprocessed image saved for 12860.png
# Preprocessed image saved for 12861.png
# Preprocessed image saved for 12862.png
# Preprocessed image saved for 12863.png
# Preprocessed image saved for 12864.png
# Preprocessed image saved for 12866.png
# Preprocessed image saved for 12867.png
# Preprocessed image saved for 12869.png
# Preprocessed image saved for 12870.png
# Preprocessed image saved for 12871.png
# Preprocessed image saved for 12873.png
# Preprocessed image saved for 12874.png
# Preprocessed image saved for 12875.png
# Preprocessed image saved for 12876.png
# Preprocessed image saved for 12878.png
# Preprocessed image saved for 12879.png
# Preprocessed image saved for 12880.png
# Preprocessed image saved for 12881.png
# Preprocessed image saved for 12882.png
# Preprocessed image saved for 12883.png
# Preprocessed image saved for 12884.png
# Preprocessed image saved for 12885.png
# Preprocessed image saved for 12886.png
# Preprocessed image saved for 12887.png
# Preprocessed image saved for 12888.png
# Preprocessed image saved for 12889.png
# Preprocessed image saved for 12890.png
# Preprocessed image saved for 12891.png
# Preprocessed image saved for 12892.png
# Preprocessed image saved for 12893.png
# Preprocessed image saved for 12894.png
# Preprocessed image saved for 12895.png
# Preprocessed image saved for 12896.png
# Preprocessed image saved for 12897.png
# Preprocessed image saved for 12898.png
# Preprocessed image saved for 12899.png
# Preprocessed image saved for 12900.png
# Preprocessed image saved for 12901.png
# Preprocessed image saved for 12902.png
# Preprocessed image saved for 12904.png
# Preprocessed image saved for 12905.png
# Preprocessed image saved for 12906.png
# Preprocessed image saved for 12907.png
# Preprocessed image saved for 12908.png
# Preprocessed image saved for 12910.png
# Preprocessed image saved for 12914.png
# Preprocessed image saved for 12931.png
# Preprocessed image saved for 12939.png
# Preprocessed image saved for 12947.png
# Preprocessed image saved for 12952.png
# Preprocessed image saved for 12970.png
# Preprocessed image saved for 12978.png
# Preprocessed image saved for 12995.png
# Preprocessed image saved for 12996.png
# Preprocessed image saved for 13008.png
# Preprocessed image saved for 13009.png
# Preprocessed image saved for 13013.png
# Preprocessed image saved for 13037.png
# Preprocessed image saved for 13039.png
# Preprocessed image saved for 13041.png
# Preprocessed image saved for 13054.png
# Preprocessed image saved for 13061.png
# Preprocessed image saved for 13066.png
# Preprocessed image saved for 13073.png
# Preprocessed image saved for 13077.png
# Preprocessed image saved for 13112.png
# Preprocessed image saved for 13113.png
# Preprocessed image saved for 13133.png
# Preprocessed image saved for 13140.png
# Preprocessed image saved for 13161.png
# Preprocessed image saved for 13182.png
# Preprocessed image saved for 13184.png
# Preprocessed image saved for 13187.png
# Preprocessed image saved for 13188.png
# Preprocessed image saved for 13198.png
# Preprocessed image saved for 13203.png
# Preprocessed image saved for 13212.png
# Preprocessed image saved for 13228.png
# Preprocessed image saved for 13236.png
# Preprocessed image saved for 13241.png
# Preprocessed image saved for 13265.png
# Preprocessed image saved for 13278.png
# Preprocessed image saved for 13287.png
# Preprocessed image saved for 13290.png
# Preprocessed image saved for 13317.png
# Preprocessed image saved for 13322.png
# Preprocessed image saved for 13324.png
# Preprocessed image saved for 13335.png
# Preprocessed image saved for 13362.png
# Preprocessed image saved for 13367.png
# Preprocessed image saved for 13372.png
# Preprocessed image saved for 13393.png
# Preprocessed image saved for 13429.png
# Preprocessed image saved for 13430.png
# Preprocessed image saved for 13433.png
# Preprocessed image saved for 13444.png
# Preprocessed image saved for 13471.png
# Preprocessed image saved for 13474.png
# All images have been processed and saved.
